# %% [markdown]
# **This notebook is an exercise in the [Intro to Deep Learning](https://www.kaggle.com/learn/intro-to-deep-learning) course.  You can reference the tutorial at [this link](https://www.kaggle.com/ryanholbrook/binary-classification).**
#
# ---

# %% [markdown]
# # Introduction #
#
# In this exercise, you'll build a model to predict hotel cancellations with a binary classifier.

# %%
# Setup plotting
import matplotlib.pyplot as plt
plt.style.use('seaborn-whitegrid')
# Set Matplotlib defaults
plt.rc('figure', autolayout=True)
plt.rc('axes', labelweight='bold', labelsize='large',
       titleweight='bold', titlesize=18, titlepad=10)
plt.rc('animation', html='html5')

# Setup feedback system
from learntools.core import binder
binder.bind(globals())
from learntools.deep_learning_intro.ex6 import *

# %% [markdown]
# First, load the *Hotel Cancellations* dataset.

# %%
import pandas as pd

from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler, OneHotEncoder
from sklearn.impute import SimpleImputer
from sklearn.pipeline import make_pipeline
from sklearn.compose import make_column_transformer

hotel = pd.read_csv('../input/dl-course-data/hotel.csv')

X = hotel.copy()
y = X.pop('is_canceled')

X['arrival_date_month'] = \
    X['arrival_date_month'].map(
        {'January':1, 'February': 2, 'March':3,
         'April':4, 'May':5, 'June':6, 'July':7,
         'August':8, 'September':9, 'October':10,
         'November':11, 'December':12}
    )

features_num = [
    "lead_time", "arrival_date_week_number",
    "arrival_date_day_of_month", "stays_in_weekend_nights",
    "stays_in_week_nights", "adults", "children", "babies",
    "is_repeated_guest", "previous_cancellations",
    "previous_bookings_not_canceled", "required_car_parking_spaces",
    "total_of_special_requests", "adr",
]
features_cat = [
    "hotel", "arrival_date_month", "meal",
    "market_segment", "distribution_channel",
    "reserved_room_type", "deposit_type", "customer_type",
]

transformer_num = make_pipeline(
    SimpleImputer(strategy="constant"), # there are a few missing values
    StandardScaler(),
)
transformer_cat = make_pipeline(
    SimpleImputer(strategy="constant", fill_value="NA"),
    OneHotEncoder(handle_unknown='ignore'),
)

preprocessor = make_column_transformer(
    (transformer_num, features_num),
    (transformer_cat, features_cat),
)

# stratify - make sure classes are evenlly represented across splits
X_train, X_valid, y_train, y_valid = \
    train_test_split(X, y, stratify=y, train_size=0.75)

X_train = preprocessor.fit_transform(X_train)
X_valid = preprocessor.transform(X_valid)

input_shape = [X_train.shape[1]]

# %% [markdown]
# # 1) Define Model #
#
# The model we'll use this time will have both batch normalization and dropout layers. To ease reading we've broken the diagram into blocks, but you can define it layer by layer as usual.
#
# Define a model with an architecture given by this diagram:
#
# <figure style="padding: 1em;">
# <img src="https://i.imgur.com/V04o59Z.png" width="400" alt="Diagram of network architecture: BatchNorm, Dense, BatchNorm, Dropout, Dense, BatchNorm, Dropout, Dense.">
# <figcaption style="textalign: center; font-style: italic"><center>Diagram of a binary classifier.</center></figcaption>
# </figure>

# %%
from tensorflow import keras
from tensorflow.keras import layers

# YOUR CODE HERE: define the model given in the diagram
model = keras.Sequential([
    layers.BatchNormalization(input_shape = input_shape),
    layers.Dense(256, activation = 'relu'),
    layers.BatchNormalization(),
    layers.Dropout(rate = 0.3),
    layers.Dense(256, activation = 'relu'),
    layers.BatchNormalization(),
    layers.Dropout(rate = 0.3),
    layers.Dense(1, activation = 'sigmoid')
])

# Check your answer
q_1.check()
# Out:
# 2022-10-14 16:26:02.308725: I tensorflow/core/common_runtime/process_util.cc:146] Creating new thread pool with default inter op setting: 2. Tune using inter_op_parallelism_threads for best performance.
# Correct

# %% [markdown]
# # 2) Add Optimizer, Loss, and Metric #
#
# Now compile the model with the Adam optimizer and binary versions of the cross-entropy loss and accuracy metric.

# %%
# YOUR CODE HERE
model.compile(
    optimizer = 'adam',
    loss = 'binary_crossentropy',
    metrics = ['binary_accuracy']
)

# Check your answer
q_2.check()
# Out:
# Correct

# %%
# Lines below will give you a hint or solution code
#q_2.hint()
#q_2.solution()

# %% [markdown]
# Finally, run this cell to train the model and view the learning curves. It may run for around 60 to 70 epochs, which could take a minute or two.

# %%
early_stopping = keras.callbacks.EarlyStopping(
    patience=5,
    min_delta=0.001,
    restore_best_weights=True,
)
history = model.fit(
    X_train, y_train,
    validation_data=(X_valid, y_valid),
    batch_size=512,
    epochs=200,
    callbacks=[early_stopping],
)

history_df = pd.DataFrame(history.history)
history_df.loc[:, ['loss', 'val_loss']].plot(title="Cross-entropy")
history_df.loc[:, ['binary_accuracy', 'val_binary_accuracy']].plot(title="Accuracy")
# Out:
# 2022-10-14 16:28:08.135859: I tensorflow/compiler/mlir/mlir_graph_optimization_pass.cc:185] None of the MLIR Optimization Passes are enabled (registered 2)
# Epoch 1/200
# 175/175 [==============================] - 5s 22ms/step - loss: 0.4753 - binary_accuracy: 0.7735 - val_loss: 0.4353 - val_binary_accuracy: 0.8030
# Epoch 2/200
# 175/175 [==============================] - 4s 21ms/step - loss: 0.4224 - binary_accuracy: 0.8019 - val_loss: 0.4014 - val_binary_accuracy: 0.8145
# Epoch 3/200
# 175/175 [==============================] - 4s 22ms/step - loss: 0.4073 - binary_accuracy: 0.8085 - val_loss: 0.3937 - val_binary_accuracy: 0.8185
# Epoch 4/200
# 175/175 [==============================] - 3s 19ms/step - loss: 0.4008 - binary_accuracy: 0.8124 - val_loss: 0.3885 - val_binary_accuracy: 0.8203
# Epoch 5/200
# 175/175 [==============================] - 3s 19ms/step - loss: 0.3962 - binary_accuracy: 0.8144 - val_loss: 0.3862 - val_binary_accuracy: 0.8219
# Epoch 6/200
# 175/175 [==============================] - 3s 19ms/step - loss: 0.3917 - binary_accuracy: 0.8184 - val_loss: 0.3832 - val_binary_accuracy: 0.8262
# Epoch 7/200
# 175/175 [==============================] - 3s 19ms/step - loss: 0.3868 - binary_accuracy: 0.8208 - val_loss: 0.3792 - val_binary_accuracy: 0.8266
# Epoch 8/200
# 175/175 [==============================] - 3s 19ms/step - loss: 0.3852 - binary_accuracy: 0.8214 - val_loss: 0.3774 - val_binary_accuracy: 0.8295
# Epoch 9/200
# 175/175 [==============================] - 3s 19ms/step - loss: 0.3821 - binary_accuracy: 0.8215 - val_loss: 0.3836 - val_binary_accuracy: 0.8258
# Epoch 10/200
# 175/175 [==============================] - 3s 19ms/step - loss: 0.3781 - binary_accuracy: 0.8239 - val_loss: 0.3765 - val_binary_accuracy: 0.8289
# Epoch 11/200
# 175/175 [==============================] - 3s 19ms/step - loss: 0.3755 - binary_accuracy: 0.8261 - val_loss: 0.3733 - val_binary_accuracy: 0.8302
# Epoch 12/200
# 175/175 [==============================] - 4s 21ms/step - loss: 0.3744 - binary_accuracy: 0.8265 - val_loss: 0.3744 - val_binary_accuracy: 0.8296
# Epoch 13/200
# 175/175 [==============================] - 3s 18ms/step - loss: 0.3718 - binary_accuracy: 0.8278 - val_loss: 0.3679 - val_binary_accuracy: 0.8324
# Epoch 14/200
# 175/175 [==============================] - 3s 19ms/step - loss: 0.3700 - binary_accuracy: 0.8278 - val_loss: 0.3666 - val_binary_accuracy: 0.8338
# Epoch 15/200
# 175/175 [==============================] - 3s 19ms/step - loss: 0.3665 - binary_accuracy: 0.8305 - val_loss: 0.3641 - val_binary_accuracy: 0.8350
# Epoch 16/200
# 175/175 [==============================] - 3s 20ms/step - loss: 0.3654 - binary_accuracy: 0.8305 - val_loss: 0.3675 - val_binary_accuracy: 0.8317
# Epoch 17/200
# 175/175 [==============================] - 3s 19ms/step - loss: 0.3634 - binary_accuracy: 0.8328 - val_loss: 0.3647 - val_binary_accuracy: 0.8341
# Epoch 18/200
# 175/175 [==============================] - 3s 19ms/step - loss: 0.3629 - binary_accuracy: 0.8324 - val_loss: 0.3635 - val_binary_accuracy: 0.8357
# Epoch 19/200
# 175/175 [==============================] - 3s 19ms/step - loss: 0.3606 - binary_accuracy: 0.8328 - val_loss: 0.3605 - val_binary_accuracy: 0.8369
# Epoch 20/200
# 175/175 [==============================] - 3s 18ms/step - loss: 0.3597 - binary_accuracy: 0.8328 - val_loss: 0.3599 - val_binary_accuracy: 0.8367
# Epoch 21/200
# 175/175 [==============================] - 3s 18ms/step - loss: 0.3579 - binary_accuracy: 0.8344 - val_loss: 0.3617 - val_binary_accuracy: 0.8368
# Epoch 22/200
# 175/175 [==============================] - 4s 21ms/step - loss: 0.3559 - binary_accuracy: 0.8349 - val_loss: 0.3598 - val_binary_accuracy: 0.8362
# Epoch 23/200
# 175/175 [==============================] - 3s 19ms/step - loss: 0.3555 - binary_accuracy: 0.8353 - val_loss: 0.3601 - val_binary_accuracy: 0.8361
# Epoch 24/200
# 175/175 [==============================] - 3s 19ms/step - loss: 0.3541 - binary_accuracy: 0.8364 - val_loss: 0.3552 - val_binary_accuracy: 0.8396
# Epoch 25/200
# 175/175 [==============================] - 3s 20ms/step - loss: 0.3529 - binary_accuracy: 0.8361 - val_loss: 0.3554 - val_binary_accuracy: 0.8397
# Epoch 26/200
# 175/175 [==============================] - 3s 18ms/step - loss: 0.3519 - binary_accuracy: 0.8374 - val_loss: 0.3580 - val_binary_accuracy: 0.8378
# Epoch 27/200
# 175/175 [==============================] - 3s 18ms/step - loss: 0.3508 - binary_accuracy: 0.8375 - val_loss: 0.3568 - val_binary_accuracy: 0.8390
# Epoch 28/200
# 175/175 [==============================] - 3s 18ms/step - loss: 0.3495 - binary_accuracy: 0.8390 - val_loss: 0.3543 - val_binary_accuracy: 0.8393
# Epoch 29/200
# 175/175 [==============================] - 3s 19ms/step - loss: 0.3487 - binary_accuracy: 0.8392 - val_loss: 0.3544 - val_binary_accuracy: 0.8388
# <AxesSubplot:title={'center':'Accuracy'}>

# %% [markdown]
# # 3) Train and Evaluate #
#
#
# What do you think about the learning curves? Does it look like the model underfit or overfit? Was the cross-entropy loss a good stand-in for accuracy?

# %%
# View the solution (Run this cell to receive credit!)
q_3.check()
# Out:
# Correct:
#
# Though we can see the training loss continuing to fall, the early stopping callback prevented any overfitting. Moreover, the accuracy rose at the same rate as the cross-entropy fell, so it appears that minimizing cross-entropy was a good stand-in. All in all, it looks like this training was a success!

# %% [markdown]
# # Conclusion #
#
# Congratulations! You've completed Kaggle's *Introduction to Deep Learning* course!
#
# With your new skills you're ready to take on more advanced applications like computer vision and sentiment classification. What would you like to do next?
#
# Why not try one of our *Getting Started* competitions?
#
# - Classify images with TPUs in [**Petals to the Metal**](https://www.kaggle.com/c/tpu-getting-started)
# - Create art with GANs in [**I'm Something of a Painter Myself**](https://www.kaggle.com/c/gan-getting-started)
# - Classify Tweets in [**Real or Not? NLP with Disaster Tweets**](https://www.kaggle.com/c/nlp-getting-started)
# - Detect contradiction and entailment in [**Contradictory, My Dear Watson**](https://www.kaggle.com/c/contradictory-my-dear-watson)
#
# Until next time, Kagglers!

# %% [markdown]
# ---
#
#
#
#
# *Have questions or comments? Visit the [course discussion forum](https://www.kaggle.com/learn/intro-to-deep-learning/discussion) to chat with other learners.*
